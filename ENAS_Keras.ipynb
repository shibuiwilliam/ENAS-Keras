# %%
import numpy as np
import os
import sys
import shutil
import gc

import keras
from keras import backend as K
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping

import tensorflow as tf

from IPython.display import clear_output

# %%
from src.child_network_micro_search import NetworkOperation
from src.child_network_micro_search import NetworkOperationController
from src.child_network_micro_search import CellGenerator
from src.child_network_micro_search import ChildNetworkGenerator
from src.child_network_micro_search import ChildNetworkManager

from src.controller_network import ControllerRNNGenerator
from src.controller_network import ControllerRNNManager
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Set GPU option to allow_growth=False

# %%
config = tf.ConfigProto(
    gpu_options=tf.GPUOptions(
        allow_growth=False
    )
)
sess = tf.Session(config=config)
K.set_session(sess)

# %%
# Load Cifar10 dataset

# %%
child_classes = 10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = to_categorical(y_train, child_classes)
y_test = to_categorical(y_test, child_classes)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)
# y_train shape: (50000, 10)
# y_test shape: (10000, 10)
# 50000 train samples
# 10000 test samples

# %%
# Common parameters
num_nodes=6
num_opers=5
search_epochs = 100
sample_nums = 10
_sep = "-"*10

# Parameters for controller RNN
reward = 0
controller_input_x = np.array([[[num_opers+num_nodes]]])
controller_lstm_cell_units = 32
controller_baseline_decay = 0.99
controller_opt = Adam(lr=0.0001, decay=1e-6, amsgrad=True)

controller_batch_size = 1
controller_epochs = 50
controller_callbacks = [EarlyStopping(monitor='val_loss', patience=1, verbose=1, mode='auto')]

controller_temperature = 5.0
controller_tanh_constant = 2.5

# Parameters for child network
child_network_name="cifar10_cnn"
child_input_shape=(32,32,3)
child_init_filters=64
child_network_definition=["N","N","R","N","N","R"]
child_weight_directory="./weights"
initialize_child_weight_directory=True

child_opt_loss='categorical_crossentropy'
child_opt=Adam(lr=0.0001, decay=1e-6, amsgrad=True)
child_opt_metrics=['accuracy']

child_val_index = [i for i in range(len(y_test))]
child_val_batch_size = 256

child_batch_size = 32
child_epochs = 50
child_callbacks = [EarlyStopping(monitor='val_loss', patience=1, verbose=1, mode='auto')]

child_data_gen = ImageDataGenerator(
    rotation_range=90, 
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True)

child_train_records = []

if initialize_child_weight_directory:
  if os.path.exists(child_weight_directory):
    shutil.rmtree(child_weight_directory)

# %%
# Controller RNN

NCR = ControllerRNNGenerator(controller_network_name="normalcontroller",
                             num_nodes=num_nodes,
                             num_opers=num_opers,
                             lstm_cell_units=controller_lstm_cell_units,
                             baseline_decay=controller_baseline_decay,
                             opt=controller_opt)
RCR = ControllerRNNGenerator(controller_network_name="reductioncontroller",
                             num_nodes=num_nodes,
                             num_opers=num_opers,
                             lstm_cell_units=controller_lstm_cell_units,
                             baseline_decay=controller_baseline_decay,
                             opt=controller_opt)

NCRM = ControllerRNNManager(controller_rnn_instance = NCR,
                            input_x = controller_input_x,
                            reward = reward,
                            temperature = controller_temperature,
                            tanh_constant = controller_tanh_constant)
RCRM = ControllerRNNManager(controller_rnn_instance = RCR,
                            input_x = controller_input_x,
                            reward = reward,
                            temperature = controller_temperature,
                            tanh_constant = controller_tanh_constant)

# %%
# Efficient neural architecture search
## Micro search for CNN cells

# %%
for e in range(search_epochs):
  print("SEARCH EPOCH: {0} / {1}".format(e, search_epochs))
  print("{0} sampling cells {0}".format(_sep))
  normal_controller_pred = NCRM.softmax_predict()
  reduction_controller_pred = RCRM.softmax_predict()

  normal_pred_dict = NCRM.convert_pred_to_ydict(normal_controller_pred)
  reduction_pred_dict = RCRM.convert_pred_to_ydict(reduction_controller_pred)

  sample_cells = []
  for _ in range(sample_nums):
    sample_cell = {}
    random_normal_pred = NCRM.random_sample_softmax(normal_controller_pred)
    random_reduction_pred = RCRM.random_sample_softmax(reduction_controller_pred)

    sample_cell["normal_cell"] = NCRM.convert_pred_to_cell(random_normal_pred)
    sample_cell["reduction_cell"] = RCRM.convert_pred_to_cell(random_reduction_pred)
    sample_cells.append(sample_cell)

  val_batch = np.random.choice(child_val_index,
                               child_val_batch_size, 
                               replace=False)
  x_val_batch = x_test[val_batch]
  y_val_batch = y_test[val_batch]
  best_val_acc = 0
  best_cell_index = 0

  for i in range(len(sample_cells)):
    print("{0} evaluating sample: {1} {0}\ncell: ".format(_sep, 
                                                          i))
    for k,v in sample_cells[i].items():
      print("{0}: {1}".format(k,v))
    NO = NetworkOperation()
    NOC = NetworkOperationController(network_name=child_network_name,
                                     classes=child_classes,
                                     input_shape=child_input_shape,
                                     init_filters=child_init_filters,
                                     NetworkOperationInstance=NO)
    CG = CellGenerator(num_nodes=num_nodes,                   
                       normal_cell=sample_cells[i]["normal_cell"],
                       reduction_cell=sample_cells[i]["reduction_cell"],
                       NetworkOperationControllerInstance=NOC)
    CNG = ChildNetworkGenerator(child_network_definition=child_network_definition,
                                CellGeneratorInstance=CG,
                                opt_loss=child_opt_loss,
                                opt=child_opt,
                                opt_metrics=child_opt_metrics)

    CNM = ChildNetworkManager(weight_directory=child_weight_directory)
    CNM.set_model(CNG.generate_child_network())    
    CNM.set_weight_to_layer()
    val_acc = CNM.evaluate_child_network(x_val_batch, y_val_batch)
    print(val_acc)
    if best_val_acc < val_acc[1]:
      best_val_acc = val_acc[1]
      best_cell_index = i
    del CNM.model
    del CNM
    del CNG
    del CG
    del NOC
    del NO
    for j in range(30):
      gc.collect()

  print("best val accuracy: {0}\nthe current best cell:".format(best_val_acc))
  for k,v in sample_cells[best_cell_index].items():
    print("{0}: {1}".format(k,v))
  print("{0} train child network with the current best cell {0}".format(_sep))
    
  NO = NetworkOperation()
  NOC = NetworkOperationController(network_name=child_network_name,
                                   classes=child_classes,
                                   input_shape=child_input_shape,
                                   init_filters=child_init_filters,
                                   NetworkOperationInstance=NO)
  CG = CellGenerator(num_nodes=num_nodes,                   
                     normal_cell=sample_cells[best_cell_index]["normal_cell"],
                     reduction_cell=sample_cells[best_cell_index]["reduction_cell"],
                     NetworkOperationControllerInstance=NOC)
  CNG = ChildNetworkGenerator(child_network_definition=child_network_definition,
                              CellGeneratorInstance=CG,
                              opt_loss=child_opt_loss,
                              opt=child_opt,
                              opt_metrics=child_opt_metrics)

  CNM = ChildNetworkManager(weight_directory=child_weight_directory)
  CNM.set_model(CNG.generate_child_network())
  print("MODEL SUMMARY: {0}\n".format(CNM.model.summary()))
  CNM.set_weight_to_layer()
  CNM.train_child_network(x_train=x_train, y_train=y_train,
                          validation_data=(x_test, y_test),
                          batch_size = child_batch_size,
                          epochs = child_epochs,
                          callbacks=child_callbacks,
                          data_gen=child_data_gen)
  CNM.save_layer_weight()
  print("{0} training finished {0}".format(_sep))

  val_acc = CNM.evaluate_child_network(x_test, y_test)
  reward = val_acc[1]
  print("evaluation loss: {0}\nevaluation acc: {1}".format(val_acc[0],
                                                           val_acc[1]))

  child_train_record = {}
  child_train_record["normal_cell"] = sample_cells[best_cell_index]["normal_cell"]
  child_train_record["reduction_cell"] = sample_cells[best_cell_index]["reduction_cell"]
  child_train_record["val_loss"] = val_acc[0]
  child_train_record["reward"] = val_acc[1]
  print("epoch: {0}\nrecord: ".format(e))
  for k,v in child_train_record.items():
    print("{0}: {1}".format(k,v))
  child_train_records.append(train_record)
    
  if e == search_epochs - 1:
    clear_output(wait=True)
    break
    
  del CNM.model
  del CNM
  del CNG
  del CG
  del NOC
  del NO
  for j in range(30):
    gc.collect()

    
  print("{0} train controller rnn {0}".format(_sep))

  NCRM.reward = reward
  RCRM.reward = reward
  NCRM.train_controller_rnn(targets=normal_pred_dict,
                            batch_size = controller_batch_size,
                            epochs = controller_epochs,
                            callbacks=controller_callbacks)
  RCRM.train_controller_rnn(targets=reduction_pred_dict,
                            batch_size = controller_batch_size,
                            epochs = controller_epochs,
                            callbacks=controller_callbacks)
  print("{0} training finished {0}".format(_sep))
  print("{0} FINISHED SEARCH EPOCH {1} / {2} {0}".format(_sep,
                                                         e, 
                                                         search_epochs))
  clear_output(wait=True)
    
print("{0} FINISHED NEURAL ARCHITECTURE SEARCH {0}".format(_sep))
print("training records:\n{0}".format(child_train_records))
print("final child network:\n{0}".format(CNM.model.summary()))
# Out:
# SEARCH EPOCH: 0 / 100
# ---------- sampling cells ----------
# ---------- evaluating sample: 0 ----------
# cell:
# normal_cell: {2: {'L': [1, 2], 'R': [0, 1]}, 3: {'L': [1, 2], 'R': [0, 2]}, 4: {'L': [2, 2], 'R': [3, 3]}, 5: {'L': [2, 0], 'R': [4, 1]}}
# reduction_cell: {2: {'L': [1, 1], 'R': [1, 2]}, 3: {'L': [1, 4], 'R': [2, 1]}, 4: {'L': [3, 0], 'R': [0, 4]}, 5: {'L': [1, 1], 'R': [4, 3]}}
# 256/256 [==============================] - 7s 26ms/step
# [3.7777808904647827, 0.109375]
# ---------- evaluating sample: 1 ----------
# cell:
# normal_cell: {2: {'L': [1, 0], 'R': [0, 2]}, 3: {'L': [0, 3], 'R': [1, 1]}, 4: {'L': [0, 2], 'R': [0, 2]}, 5: {'L': [0, 2], 'R': [3, 0]}}
# reduction_cell: {2: {'L': [1, 1], 'R': [1, 1]}, 3: {'L': [2, 0], 'R': [2, 2]}, 4: {'L': [1, 1], 'R': [2, 3]}, 5: {'L': [2, 4], 'R': [0, 1]}}
# 256/256 [==============================] - 8s 32ms/step
# [3.8411253094673157, 0.078125]
# ---------- evaluating sample: 2 ----------
# cell:
# normal_cell: {2: {'L': [0, 3], 'R': [0, 2]}, 3: {'L': [1, 0], 'R': [0, 0]}, 4: {'L': [0, 0], 'R': [3, 0]}, 5: {'L': [1, 4], 'R': [1, 2]}}
# reduction_cell: {2: {'L': [1, 2], 'R': [1, 4]}, 3: {'L': [0, 4], 'R': [1, 0]}, 4: {'L': [3, 2], 'R': [0, 4]}, 5: {'L': [3, 1], 'R': [3, 3]}}
# 256/256 [==============================] - 10s 39ms/step
# [5.070276379585266, 0.1328125]
# ---------- evaluating sample: 3 ----------
# cell:
# normal_cell: {2: {'L': [1, 3], 'R': [1, 0]}, 3: {'L': [1, 2], 'R': [2, 0]}, 4: {'L': [3, 4], 'R': [0, 2]}, 5: {'L': [0, 3], 'R': [1, 0]}}
# reduction_cell: {2: {'L': [1, 4], 'R': [0, 2]}, 3: {'L': [1, 0], 'R': [1, 1]}, 4: {'L': [3, 0], 'R': [0, 1]}, 5: {'L': [1, 4], 'R': [4, 3]}}
# 256/256 [==============================] - 10s 40ms/step
# [8.594569385051727, 0.11328125]
# ---------- evaluating sample: 4 ----------
# cell:
# normal_cell: {2: {'L': [1, 2], 'R': [1, 3]}, 3: {'L': [2, 1], 'R': [0, 2]}, 4: {'L': [0, 1], 'R': [3, 0]}, 5: {'L': [2, 0], 'R': [1, 4]}}
# reduction_cell: {2: {'L': [0, 1], 'R': [1, 4]}, 3: {'L': [0, 2], 'R': [0, 0]}, 4: {'L': [3, 4], 'R': [3, 4]}, 5: {'L': [1, 2], 'R': [3, 4]}}
# 256/256 [==============================] - 11s 43ms/step
# [3.6309401392936707, 0.078125]
# ---------- evaluating sample: 5 ----------
# cell:
# normal_cell: {2: {'L': [0, 1], 'R': [0, 0]}, 3: {'L': [2, 4], 'R': [2, 2]}, 4: {'L': [3, 3], 'R': [3, 4]}, 5: {'L': [4, 2], 'R': [1, 4]}}
# reduction_cell: {2: {'L': [1, 0], 'R': [1, 1]}, 3: {'L': [1, 4], 'R': [2, 4]}, 4: {'L': [3, 0], 'R': [3, 2]}, 5: {'L': [1, 4], 'R': [4, 3]}}
# 256/256 [==============================] - 10s 38ms/step
# [7.149158358573914, 0.08984375]
# ---------- evaluating sample: 6 ----------
# cell:
# normal_cell: {2: {'L': [1, 2], 'R': [1, 4]}, 3: {'L': [2, 4], 'R': [0, 1]}, 4: {'L': [0, 4], 'R': [2, 4]}, 5: {'L': [1, 3], 'R': [3, 4]}}
# reduction_cell: {2: {'L': [0, 1], 'R': [0, 4]}, 3: {'L': [1, 1], 'R': [1, 2]}, 4: {'L': [0, 3], 'R': [3, 0]}, 5: {'L': [3, 4], 'R': [2, 0]}}
# 256/256 [==============================] - 11s 42ms/step
# [9.11799418926239, 0.08984375]
# ---------- evaluating sample: 7 ----------
# cell:
# normal_cell: {2: {'L': [1, 2], 'R': [0, 2]}, 3: {'L': [0, 3], 'R': [2, 3]}, 4: {'L': [3, 3], 'R': [2, 1]}, 5: {'L': [4, 1], 'R': [1, 2]}}
# reduction_cell: {2: {'L': [0, 1], 'R': [0, 4]}, 3: {'L': [1, 1], 'R': [2, 0]}, 4: {'L': [3, 0], 'R': [0, 2]}, 5: {'L': [2, 4], 'R': [4, 0]}}
# 256/256 [==============================] - 13s 51ms/step
# [4.587639212608337, 0.1171875]
# ---------- evaluating sample: 8 ----------
# cell:
# normal_cell: {2: {'L': [1, 4], 'R': [0, 4]}, 3: {'L': [1, 3], 'R': [0, 2]}, 4: {'L': [2, 0], 'R': [3, 2]}, 5: {'L': [4, 2], 'R': [1, 0]}}
# reduction_cell: {2: {'L': [0, 2], 'R': [1, 2]}, 3: {'L': [1, 3], 'R': [1, 1]}, 4: {'L': [3, 3], 'R': [1, 1]}, 5: {'L': [0, 0], 'R': [1, 1]}}
# 256/256 [==============================] - 14s 55ms/step
# [9.918330073356628, 0.109375]
# ---------- evaluating sample: 9 ----------
# cell:
# normal_cell: {2: {'L': [0, 2], 'R': [0, 4]}, 3: {'L': [0, 2], 'R': [1, 4]}, 4: {'L': [2, 1], 'R': [3, 1]}, 5: {'L': [2, 2], 'R': [1, 0]}}
# reduction_cell: {2: {'L': [0, 4], 'R': [0, 3]}, 3: {'L': [2, 4], 'R': [2, 2]}, 4: {'L': [3, 3], 'R': [3, 1]}, 5: {'L': [1, 1], 'R': [1, 2]}}
# 256/256 [==============================] - 16s 62ms/step
# [9.831055760383606, 0.046875]
# best val accuracy: 0.1328125
# the best cell:
# normal_cell: {2: {'L': [0, 3], 'R': [0, 2]}, 3: {'L': [1, 0], 'R': [0, 0]}, 4: {'L': [0, 0], 'R': [3, 0]}, 5: {'L': [1, 4], 'R': [1, 2]}}
# reduction_cell: {2: {'L': [1, 2], 'R': [1, 4]}, 3: {'L': [0, 4], 'R': [1, 0]}, 4: {'L': [3, 2], 'R': [0, 4]}, 5: {'L': [3, 1], 'R': [3, 3]}}
# ---------- train child network with best cells ----------
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# cifar10_cnn_fixed_999_999_C_inp (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_3_L_sepcon (None, 32, 32, 3)    0           cifar10_cnn_fixed_999_999_C_input
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_3_R_sepcon (None, 32, 32, 3)    0           cifar10_cnn_fixed_999_999_C_input
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_3_L_sepcon (None, 32, 32, 64)   283         cifar10_cnn_normal_1_3_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_3_R_sepcon (None, 32, 32, 64)   283         cifar10_cnn_normal_1_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_3_L_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_1_3_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_3_R_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_1_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_3_L_sepcon (None, 32, 32, 64)   0           cifar10_cnn_normal_1_3_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_3_R_sepcon (None, 32, 32, 64)   0           cifar10_cnn_normal_1_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_3_L_sepcon (None, 32, 32, 64)   4736        cifar10_cnn_normal_1_3_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_3_R_sepcon (None, 32, 32, 64)   4736        cifar10_cnn_normal_1_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_3_L_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_1_3_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_3_R_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_1_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_3_C_add_ad (None, 32, 32, 64)   0           cifar10_cnn_normal_1_3_L_sepconv3
#                                                                  cifar10_cnn_normal_1_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_4_L_sepcon (None, 32, 32, 3)    0           cifar10_cnn_fixed_999_999_C_input
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_4_R_sepcon (None, 32, 32, 64)   0           cifar10_cnn_normal_1_3_C_add_add_
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_4_L_sepcon (None, 32, 32, 64)   283         cifar10_cnn_normal_1_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_4_R_sepcon (None, 32, 32, 64)   4736        cifar10_cnn_normal_1_4_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_2_L_avepoo (None, 32, 32, 3)    0           cifar10_cnn_fixed_999_999_C_input
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_2_R_maxpoo (None, 32, 32, 3)    0           cifar10_cnn_fixed_999_999_C_input
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_4_L_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_1_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_4_R_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_1_4_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_5_L_identi (None, 32, 32, 3)    0           cifar10_cnn_fixed_999_999_C_input
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_5_R_maxpoo (None, 32, 32, 3)    0           cifar10_cnn_fixed_999_999_C_input
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_2_L_avepoo (None, 32, 32, 3)    0           cifar10_cnn_normal_1_2_L_avepool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_2_R_maxpoo (None, 32, 32, 3)    0           cifar10_cnn_normal_1_2_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_4_L_sepcon (None, 32, 32, 64)   0           cifar10_cnn_normal_1_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_4_R_sepcon (None, 32, 32, 64)   0           cifar10_cnn_normal_1_4_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_5_L_identi (None, 32, 32, 3)    0           cifar10_cnn_normal_1_5_L_identity
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_5_R_maxpoo (None, 32, 32, 3)    0           cifar10_cnn_normal_1_5_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_2_L_avepoo (None, 32, 32, 64)   256         cifar10_cnn_normal_1_2_L_avepool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_2_R_maxpoo (None, 32, 32, 64)   256         cifar10_cnn_normal_1_2_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_4_L_sepcon (None, 32, 32, 64)   4736        cifar10_cnn_normal_1_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_4_R_sepcon (None, 32, 32, 64)   4736        cifar10_cnn_normal_1_4_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_5_L_identi (None, 32, 32, 64)   256         cifar10_cnn_normal_1_5_L_identity
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_5_R_maxpoo (None, 32, 32, 64)   256         cifar10_cnn_normal_1_5_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_2_L_avepoo (None, 32, 32, 64)   256         cifar10_cnn_normal_1_2_L_avepool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_2_R_maxpoo (None, 32, 32, 64)   256         cifar10_cnn_normal_1_2_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_4_L_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_1_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_4_R_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_1_4_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_5_L_identi (None, 32, 32, 64)   256         cifar10_cnn_normal_1_5_L_identity
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_5_R_maxpoo (None, 32, 32, 64)   256         cifar10_cnn_normal_1_5_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_2_C_add_ad (None, 32, 32, 64)   0           cifar10_cnn_normal_1_2_L_avepool3
#                                                                  cifar10_cnn_normal_1_2_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_4_C_add_ad (None, 32, 32, 64)   0           cifar10_cnn_normal_1_4_L_sepconv3
#                                                                  cifar10_cnn_normal_1_4_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_5_C_add_ad (None, 32, 32, 64)   0           cifar10_cnn_normal_1_5_L_identity
#                                                                  cifar10_cnn_normal_1_5_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_1_245_C_conc (None, 32, 32, 192)  0           cifar10_cnn_normal_1_2_C_add_add_
#                                                                  cifar10_cnn_normal_1_4_C_add_add_
#                                                                  cifar10_cnn_normal_1_5_C_add_add_
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_3_L_sepcon (None, 32, 32, 192)  0           cifar10_cnn_normal_1_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_3_R_sepcon (None, 32, 32, 3)    0           cifar10_cnn_fixed_999_999_C_input
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_3_L_sepcon (None, 32, 32, 64)   14080       cifar10_cnn_normal_2_3_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_3_R_sepcon (None, 32, 32, 64)   283         cifar10_cnn_normal_2_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_3_L_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_2_3_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_3_R_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_2_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_3_L_sepcon (None, 32, 32, 64)   0           cifar10_cnn_normal_2_3_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_3_R_sepcon (None, 32, 32, 64)   0           cifar10_cnn_normal_2_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_3_L_sepcon (None, 32, 32, 64)   4736        cifar10_cnn_normal_2_3_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_3_R_sepcon (None, 32, 32, 64)   4736        cifar10_cnn_normal_2_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_3_L_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_2_3_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_3_R_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_2_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_3_C_add_ad (None, 32, 32, 64)   0           cifar10_cnn_normal_2_3_L_sepconv3
#                                                                  cifar10_cnn_normal_2_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_4_L_sepcon (None, 32, 32, 3)    0           cifar10_cnn_fixed_999_999_C_input
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_4_R_sepcon (None, 32, 32, 64)   0           cifar10_cnn_normal_2_3_C_add_add_
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_4_L_sepcon (None, 32, 32, 64)   283         cifar10_cnn_normal_2_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_4_R_sepcon (None, 32, 32, 64)   4736        cifar10_cnn_normal_2_4_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_2_L_avepoo (None, 32, 32, 3)    0           cifar10_cnn_fixed_999_999_C_input
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_2_R_maxpoo (None, 32, 32, 3)    0           cifar10_cnn_fixed_999_999_C_input
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_4_L_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_2_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_4_R_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_2_4_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_5_L_identi (None, 32, 32, 192)  0           cifar10_cnn_normal_1_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_5_R_maxpoo (None, 32, 32, 192)  0           cifar10_cnn_normal_1_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_2_L_avepoo (None, 32, 32, 3)    0           cifar10_cnn_normal_2_2_L_avepool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_2_R_maxpoo (None, 32, 32, 3)    0           cifar10_cnn_normal_2_2_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_4_L_sepcon (None, 32, 32, 64)   0           cifar10_cnn_normal_2_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_4_R_sepcon (None, 32, 32, 64)   0           cifar10_cnn_normal_2_4_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_5_L_identi (None, 32, 32, 192)  0           cifar10_cnn_normal_2_5_L_identity
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_5_R_maxpoo (None, 32, 32, 192)  0           cifar10_cnn_normal_2_5_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_2_L_avepoo (None, 32, 32, 64)   256         cifar10_cnn_normal_2_2_L_avepool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_2_R_maxpoo (None, 32, 32, 64)   256         cifar10_cnn_normal_2_2_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_4_L_sepcon (None, 32, 32, 64)   4736        cifar10_cnn_normal_2_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_4_R_sepcon (None, 32, 32, 64)   4736        cifar10_cnn_normal_2_4_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_5_L_identi (None, 32, 32, 64)   12352       cifar10_cnn_normal_2_5_L_identity
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_5_R_maxpoo (None, 32, 32, 64)   12352       cifar10_cnn_normal_2_5_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_2_L_avepoo (None, 32, 32, 64)   256         cifar10_cnn_normal_2_2_L_avepool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_2_R_maxpoo (None, 32, 32, 64)   256         cifar10_cnn_normal_2_2_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_4_L_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_2_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_4_R_sepcon (None, 32, 32, 64)   256         cifar10_cnn_normal_2_4_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_5_L_identi (None, 32, 32, 64)   256         cifar10_cnn_normal_2_5_L_identity
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_5_R_maxpoo (None, 32, 32, 64)   256         cifar10_cnn_normal_2_5_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_2_C_add_ad (None, 32, 32, 64)   0           cifar10_cnn_normal_2_2_L_avepool3
#                                                                  cifar10_cnn_normal_2_2_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_4_C_add_ad (None, 32, 32, 64)   0           cifar10_cnn_normal_2_4_L_sepconv3
#                                                                  cifar10_cnn_normal_2_4_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_5_C_add_ad (None, 32, 32, 64)   0           cifar10_cnn_normal_2_5_L_identity
#                                                                  cifar10_cnn_normal_2_5_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_2_245_C_conc (None, 32, 32, 192)  0           cifar10_cnn_normal_2_2_C_add_add_
#                                                                  cifar10_cnn_normal_2_4_C_add_add_
#                                                                  cifar10_cnn_normal_2_5_C_add_add_
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_L_ide (None, 32, 32, 192)  0           cifar10_cnn_normal_1_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_L_ide (None, 32, 32, 192)  0           cifar10_cnn_reduction_1_3_L_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_R_ide (None, 32, 32, 192)  0           cifar10_cnn_normal_1_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_R_ide (None, 32, 32, 192)  0           cifar10_cnn_normal_2_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_L_ide (None, 32, 32, 128)  24704       cifar10_cnn_reduction_1_3_L_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_R_ide (None, 32, 32, 192)  0           cifar10_cnn_reduction_1_4_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_R_ide (None, 32, 32, 192)  0           cifar10_cnn_reduction_1_2_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_L_ide (None, 32, 32, 128)  512         cifar10_cnn_reduction_1_3_L_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_R_ide (None, 32, 32, 128)  24704       cifar10_cnn_reduction_1_4_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_R_ide (None, 32, 32, 128)  24704       cifar10_cnn_reduction_1_2_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_C_add (None, 33, 33, 128)  0           cifar10_cnn_reduction_1_3_L_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_R_sep (None, 32, 32, 192)  0           cifar10_cnn_normal_2_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_R_ide (None, 32, 32, 128)  512         cifar10_cnn_reduction_1_4_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_R_ide (None, 32, 32, 128)  512         cifar10_cnn_reduction_1_2_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_C_add (None, 32, 32, 128)  0           cifar10_cnn_reduction_1_3_C_add_z
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_R_sep (None, 16, 16, 128)  26432       cifar10_cnn_reduction_1_3_R_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 33, 33, 128)  0           cifar10_cnn_reduction_1_4_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_C_add (None, 33, 33, 128)  0           cifar10_cnn_reduction_1_2_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_C_add (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_3_L_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_C_add (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_3_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_R_sep (None, 16, 16, 128)  512         cifar10_cnn_reduction_1_3_R_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 32, 32, 128)  0           cifar10_cnn_reduction_1_4_C_add_z
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_C_add (None, 32, 32, 128)  0           cifar10_cnn_reduction_1_2_C_add_z
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_C_add (None, 16, 16, 64)   8256        cifar10_cnn_reduction_1_3_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_C_add (None, 16, 16, 64)   8256        cifar10_cnn_reduction_1_3_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_R_sep (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_3_R_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_4_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_4_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_L_max (None, 16, 16, 192)  0           cifar10_cnn_normal_2_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_C_add (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_2_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_C_add (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_2_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_R_sepcon (None, 32, 32, 192)  0           cifar10_cnn_normal_2_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_C_add (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_3_C_add_c
#                                                                  cifar10_cnn_reduction_1_3_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_R_sep (None, 16, 16, 128)  17664       cifar10_cnn_reduction_1_3_R_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 16, 16, 64)   8256        cifar10_cnn_reduction_1_4_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 16, 16, 64)   8256        cifar10_cnn_reduction_1_4_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_L_max (None, 16, 16, 192)  0           cifar10_cnn_reduction_1_2_L_maxpo
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_C_add (None, 16, 16, 64)   8256        cifar10_cnn_reduction_1_2_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_C_add (None, 16, 16, 64)   8256        cifar10_cnn_reduction_1_2_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_R_sepcon (None, 32, 32, 128)  26432       cifar10_cnn_normal_3_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_C_add (None, 16, 16, 128)  512         cifar10_cnn_reduction_1_3_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_R_sep (None, 16, 16, 128)  512         cifar10_cnn_reduction_1_3_R_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_4_C_add_c
#                                                                  cifar10_cnn_reduction_1_4_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_L_max (None, 16, 16, 128)  24704       cifar10_cnn_reduction_1_2_L_maxpo
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_C_add (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_2_C_add_c
#                                                                  cifar10_cnn_reduction_1_2_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_R_sepcon (None, 32, 32, 128)  512         cifar10_cnn_normal_3_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_3_C_add (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_3_C_add_b
#                                                                  cifar10_cnn_reduction_1_3_R_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 16, 16, 128)  512         cifar10_cnn_reduction_1_4_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_L_max (None, 16, 16, 128)  512         cifar10_cnn_reduction_1_2_L_maxpo
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_C_add (None, 16, 16, 128)  512         cifar10_cnn_reduction_1_2_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_R_sepcon (None, 32, 32, 128)  0           cifar10_cnn_normal_3_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 17, 17, 128)  0           cifar10_cnn_reduction_1_4_C_add_b
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_2_C_add (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_2_L_maxpo
#                                                                  cifar10_cnn_reduction_1_2_C_add_b
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_5_L_sep (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_3_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_R_sepcon (None, 32, 32, 128)  17664       cifar10_cnn_normal_3_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_4_C_add_z
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_245_C_c (None, 17, 17, 128)  0           cifar10_cnn_reduction_1_2_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_5_L_sep (None, 8, 8, 128)    19712       cifar10_cnn_reduction_1_5_L_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_R_sepcon (None, 32, 32, 128)  512         cifar10_cnn_normal_3_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 8, 8, 128)    0           cifar10_cnn_reduction_1_4_C_add_b
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 8, 8, 128)    0           cifar10_cnn_reduction_1_4_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_245_C_c (None, 16, 16, 128)  0           cifar10_cnn_reduction_1_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_5_L_sep (None, 8, 8, 128)    512         cifar10_cnn_reduction_1_5_L_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_C_add_ze (None, 33, 33, 128)  0           cifar10_cnn_normal_3_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_4_L_sepcon (None, 32, 32, 192)  0           cifar10_cnn_normal_2_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 8, 8, 64)     8256        cifar10_cnn_reduction_1_4_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 8, 8, 64)     8256        cifar10_cnn_reduction_1_4_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_245_C_c (None, 8, 8, 128)    0           cifar10_cnn_reduction_1_2_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_245_C_c (None, 8, 8, 128)    0           cifar10_cnn_reduction_1_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_5_L_sep (None, 8, 8, 128)    0           cifar10_cnn_reduction_1_5_L_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_C_add_cr (None, 32, 32, 128)  0           cifar10_cnn_normal_3_3_C_add_zero
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_4_L_sepcon (None, 32, 32, 128)  26432       cifar10_cnn_normal_3_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 8, 8, 128)    0           cifar10_cnn_reduction_1_4_C_add_c
#                                                                  cifar10_cnn_reduction_1_4_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_245_C_c (None, 8, 8, 64)     8256        cifar10_cnn_reduction_1_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_245_C_c (None, 8, 8, 64)     8256        cifar10_cnn_reduction_1_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_5_L_sep (None, 8, 8, 128)    19712       cifar10_cnn_reduction_1_5_L_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_C_add_av (None, 16, 16, 128)  0           cifar10_cnn_normal_3_3_R_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_C_add_av (None, 16, 16, 128)  0           cifar10_cnn_normal_3_3_C_add_crop
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_4_L_sepcon (None, 32, 32, 128)  512         cifar10_cnn_normal_3_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_L_max (None, 8, 8, 128)    0           cifar10_cnn_reduction_1_3_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 8, 8, 128)    512         cifar10_cnn_reduction_1_4_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_245_C_c (None, 8, 8, 128)    0           cifar10_cnn_reduction_1_245_C_con
#                                                                  cifar10_cnn_reduction_1_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_5_L_sep (None, 8, 8, 128)    512         cifar10_cnn_reduction_1_5_L_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_5_R_ave (None, 8, 8, 128)    0           cifar10_cnn_reduction_1_3_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_C_add_co (None, 16, 16, 64)   8256        cifar10_cnn_normal_3_3_C_add_avep
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_C_add_co (None, 16, 16, 64)   8256        cifar10_cnn_normal_3_3_C_add_avep
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_2_L_avepoo (None, 32, 32, 192)  0           cifar10_cnn_normal_2_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_2_R_maxpoo (None, 32, 32, 192)  0           cifar10_cnn_normal_2_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_4_L_sepcon (None, 32, 32, 128)  0           cifar10_cnn_normal_3_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_4_C_add (None, 8, 8, 128)    0           cifar10_cnn_reduction_1_4_L_maxpo
#                                                                  cifar10_cnn_reduction_1_4_C_add_b
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_245_C_c (None, 8, 8, 128)    512         cifar10_cnn_reduction_1_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_5_C_add (None, 8, 8, 128)    0           cifar10_cnn_reduction_1_5_L_sepco
#                                                                  cifar10_cnn_reduction_1_5_R_avepo
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_C_add_co (None, 16, 16, 128)  0           cifar10_cnn_normal_3_3_C_add_conv
#                                                                  cifar10_cnn_normal_3_3_C_add_conv
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_2_L_avepoo (None, 32, 32, 192)  0           cifar10_cnn_normal_3_2_L_avepool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_2_R_maxpoo (None, 32, 32, 192)  0           cifar10_cnn_normal_3_2_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_4_L_sepcon (None, 32, 32, 128)  17664       cifar10_cnn_normal_3_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_1_245_C_c (None, 8, 8, 384)    0           cifar10_cnn_reduction_1_4_C_add_a
#                                                                  cifar10_cnn_reduction_1_245_C_con
#                                                                  cifar10_cnn_reduction_1_5_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_C_add_bn (None, 16, 16, 128)  512         cifar10_cnn_normal_3_3_C_add_conc
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_2_L_avepoo (None, 32, 32, 128)  24704       cifar10_cnn_normal_3_2_L_avepool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_2_R_maxpoo (None, 32, 32, 128)  24704       cifar10_cnn_normal_3_2_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_4_L_sepcon (None, 32, 32, 128)  512         cifar10_cnn_normal_3_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_L_sepcon (None, 8, 8, 384)    0           cifar10_cnn_reduction_1_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_C_add_ze (None, 17, 17, 128)  0           cifar10_cnn_normal_3_3_C_add_bn_0
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_2_L_avepoo (None, 32, 32, 128)  512         cifar10_cnn_normal_3_2_L_avepool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_2_R_maxpoo (None, 32, 32, 128)  512         cifar10_cnn_normal_3_2_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_4_C_add_ze (None, 33, 33, 128)  0           cifar10_cnn_normal_3_4_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_L_sepcon (None, 8, 8, 128)    52736       cifar10_cnn_normal_3_3_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_C_add_cr (None, 16, 16, 128)  0           cifar10_cnn_normal_3_3_C_add_zero
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_2_C_add_ad (None, 32, 32, 128)  0           cifar10_cnn_normal_3_2_L_avepool3
#                                                                  cifar10_cnn_normal_3_2_R_maxpool3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_4_C_add_cr (None, 32, 32, 128)  0           cifar10_cnn_normal_3_4_C_add_zero
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_L_sepcon (None, 8, 8, 128)    512         cifar10_cnn_normal_3_3_L_sepconv3
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_C_add_av (None, 8, 8, 128)    0           cifar10_cnn_normal_3_3_C_add_bn_0
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_3_C_add_av (None, 8, 8, 128)    0           cifar10_cnn_normal_3_3_C_add_crop
# __________________________________________________________________________________________________
# cifar10_cnn_normal_3_245_C_conc (None, 33, 33, 128)  0           cifar10_cnn_normal_3_2_C_add_add_
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_R_ide (None, 8, 8, 384)    0           cifar10_cnn_reduction_2_2_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_L_ide (None, 8, 8, 256)    1024        cifar10_cnn_reduction_2_3_L_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_R_ide (None, 8, 8, 256)    98560       cifar10_cnn_reduction_2_4_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_R_ide (None, 8, 8, 256)    98560       cifar10_cnn_reduction_2_2_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_C_add (None, 9, 9, 256)    0           cifar10_cnn_reduction_2_3_L_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_R_sep (None, 8, 8, 384)    0           cifar10_cnn_normal_4_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_R_ide (None, 8, 8, 256)    1024        cifar10_cnn_reduction_2_4_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_R_ide (None, 8, 8, 256)    1024        cifar10_cnn_reduction_2_2_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_C_add (None, 8, 8, 256)    0           cifar10_cnn_reduction_2_3_C_add_z
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_R_sep (None, 4, 4, 256)    102016      cifar10_cnn_reduction_2_3_R_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 9, 9, 256)    0           cifar10_cnn_reduction_2_4_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_C_add (None, 9, 9, 256)    0           cifar10_cnn_reduction_2_2_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_C_add (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_3_L_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_C_add (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_3_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_R_sep (None, 4, 4, 256)    1024        cifar10_cnn_reduction_2_3_R_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 8, 8, 256)    0           cifar10_cnn_reduction_2_4_C_add_z
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_C_add (None, 8, 8, 256)    0           cifar10_cnn_reduction_2_2_C_add_z
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_C_add (None, 4, 4, 128)    32896       cifar10_cnn_reduction_2_3_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_C_add (None, 4, 4, 128)    32896       cifar10_cnn_reduction_2_3_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_R_sep (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_3_R_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_4_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_4_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_L_max (None, 4, 4, 384)    0           cifar10_cnn_normal_4_245_C_concat
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_C_add (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_2_R_ident
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_C_add (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_2_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_C_add (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_3_C_add_c
#                                                                  cifar10_cnn_reduction_2_3_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_R_sep (None, 4, 4, 256)    68096       cifar10_cnn_reduction_2_3_R_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 4, 4, 128)    32896       cifar10_cnn_reduction_2_4_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 4, 4, 128)    32896       cifar10_cnn_reduction_2_4_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_L_max (None, 4, 4, 384)    0           cifar10_cnn_reduction_2_2_L_maxpo
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_C_add (None, 4, 4, 128)    32896       cifar10_cnn_reduction_2_2_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_C_add (None, 4, 4, 128)    32896       cifar10_cnn_reduction_2_2_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_C_add (None, 4, 4, 256)    1024        cifar10_cnn_reduction_2_3_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_R_sep (None, 4, 4, 256)    1024        cifar10_cnn_reduction_2_3_R_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_4_C_add_c
#                                                                  cifar10_cnn_reduction_2_4_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_L_max (None, 4, 4, 256)    98560       cifar10_cnn_reduction_2_2_L_maxpo
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_C_add (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_2_C_add_c
#                                                                  cifar10_cnn_reduction_2_2_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_3_C_add (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_3_C_add_b
#                                                                  cifar10_cnn_reduction_2_3_R_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 4, 4, 256)    1024        cifar10_cnn_reduction_2_4_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_L_max (None, 4, 4, 256)    1024        cifar10_cnn_reduction_2_2_L_maxpo
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_C_add (None, 4, 4, 256)    1024        cifar10_cnn_reduction_2_2_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 5, 5, 256)    0           cifar10_cnn_reduction_2_4_C_add_b
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_2_C_add (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_2_L_maxpo
#                                                                  cifar10_cnn_reduction_2_2_C_add_b
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_5_L_sep (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_3_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_4_C_add_z
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_245_C_c (None, 5, 5, 256)    0           cifar10_cnn_reduction_2_2_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_5_L_sep (None, 2, 2, 256)    72192       cifar10_cnn_reduction_2_5_L_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 2, 2, 256)    0           cifar10_cnn_reduction_2_4_C_add_b
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 2, 2, 256)    0           cifar10_cnn_reduction_2_4_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_245_C_c (None, 4, 4, 256)    0           cifar10_cnn_reduction_2_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_5_L_sep (None, 2, 2, 256)    1024        cifar10_cnn_reduction_2_5_L_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 2, 2, 128)    32896       cifar10_cnn_reduction_2_4_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 2, 2, 128)    32896       cifar10_cnn_reduction_2_4_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_245_C_c (None, 2, 2, 256)    0           cifar10_cnn_reduction_2_2_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_245_C_c (None, 2, 2, 256)    0           cifar10_cnn_reduction_2_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_5_L_sep (None, 2, 2, 256)    0           cifar10_cnn_reduction_2_5_L_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 2, 2, 256)    0           cifar10_cnn_reduction_2_4_C_add_c
#                                                                  cifar10_cnn_reduction_2_4_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_245_C_c (None, 2, 2, 128)    32896       cifar10_cnn_reduction_2_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_245_C_c (None, 2, 2, 128)    32896       cifar10_cnn_reduction_2_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_5_L_sep (None, 2, 2, 256)    72192       cifar10_cnn_reduction_2_5_L_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_L_max (None, 2, 2, 256)    0           cifar10_cnn_reduction_2_3_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 2, 2, 256)    1024        cifar10_cnn_reduction_2_4_C_add_c
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_245_C_c (None, 2, 2, 256)    0           cifar10_cnn_reduction_2_245_C_con
#                                                                  cifar10_cnn_reduction_2_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_5_L_sep (None, 2, 2, 256)    1024        cifar10_cnn_reduction_2_5_L_sepco
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_5_R_ave (None, 2, 2, 256)    0           cifar10_cnn_reduction_2_3_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_4_C_add (None, 2, 2, 256)    0           cifar10_cnn_reduction_2_4_L_maxpo
#                                                                  cifar10_cnn_reduction_2_4_C_add_b
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_245_C_c (None, 2, 2, 256)    1024        cifar10_cnn_reduction_2_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_5_C_add (None, 2, 2, 256)    0           cifar10_cnn_reduction_2_5_L_sepco
#                                                                  cifar10_cnn_reduction_2_5_R_avepo
# __________________________________________________________________________________________________
# cifar10_cnn_reduction_2_245_C_c (None, 2, 2, 768)    0           cifar10_cnn_reduction_2_4_C_add_a
#                                                                  cifar10_cnn_reduction_2_245_C_con
#                                                                  cifar10_cnn_reduction_2_5_C_add_a
# __________________________________________________________________________________________________
# cifar10_cnn_fixed_999_999_C_cla (None, 768)          0           cifar10_cnn_reduction_2_245_C_con
# __________________________________________________________________________________________________
# cifar10_cnn_fixed_999_999_C_cla (None, 10)           7690        cifar10_cnn_fixed_999_999_C_class
# __________________________________________________________________________________________________
# cifar10_cnn_fixed_999_999_C_cla (None, 10)           0           cifar10_cnn_fixed_999_999_C_class
# ==================================================================================================
# Total params: 2,325,457
# Trainable params: 2,304,721
# Non-trainable params: 20,736
# __________________________________________________________________________________________________
# MODEL SUMMARY: None
# WARNING:tensorflow:Variable *= will be deprecated. Use variable.assign_mul if you want assignment to the variable value or 'x = x * y' if you want a new python Tensor object.
# Epoch 1/50
# 1305/1563 [========================>.....] - ETA: 1:38 - loss: 3.2979 - acc: 0.3951
